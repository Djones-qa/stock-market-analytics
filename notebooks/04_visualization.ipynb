# %% [markdown]
# # 04 - Visualization & Insights
# Generate all static plots and interactive dashboards.

# %%
import sys
sys.path.append('..')
import pandas as pd
from visualizations.plots import generate_all_plots
from visualizations.dashboard import export_dashboards
from eda.exploratory_analysis import run_full_eda

# %%
df = pd.read_csv('../data/processed/prices_processed.csv')
print(f'Loaded {len(df):,} rows')

# %%
run_full_eda(df)

# %%
generate_all_plots(df, output_dir='../visualizations/output')

# %%
export_dashboards(df, output_dir='../visualizations/output')
print('All visualizations complete.')
